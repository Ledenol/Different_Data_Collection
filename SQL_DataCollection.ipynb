# %%
import pyodbc

# %%
        server = 'BT05144'  
        database = 'Blogged_Database'
        cnxn_str = (
            "DRIVER={ODBC Driver 17 for SQL Server};"
            f"SERVER={server};"
            f"DATABASE={database};"
            "Trusted_Connection=yes;"
        )

# %%
cnxn = pyodbc.connect(cnxn_str)
cursor = cnxn.cursor()

cursor.execute("Select * From BlogData")

for row in cursor.fetchall():
    print(row)
# Out:
# (3, '72c54406-d3fd-4e08-957c-1eb7f20639a5', 'testBlog', 'Hi this is a test blog', datetime.datetime(2025, 5, 15, 14, 22, 56, 530000))
# (10002, '72c54406-d3fd-4e08-957c-1eb7f20639a5', 'testBlog', 'Hi this is a test blog', datetime.datetime(2025, 7, 9, 22, 15, 2, 423000))
